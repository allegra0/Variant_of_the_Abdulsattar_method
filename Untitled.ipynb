# %%
from __future__ import print_function
import pickle
import os
#from google_auth_oauthlib.flow import Flow, InstalledAppFlow
from googleapiclient.http import MediaFileUpload, MediaIoBaseDownload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from pydrive.drive import GoogleDrive
from pydrive.auth import GoogleAuth
import google.auth
import google
from googleapiclient.discovery import build
from google.cloud import storage

from google.oauth2 import service_account
from googleapiclient.errors import HttpError


import json
import os
import hachage

def Create_Service(client_secret_file, api_name, api_version, *scopes):
    CLIENT_SECRET_FILE = client_secret_file
    API_SERVICE_NAME = api_name
    API_VERSION = api_version
    SCOPES = [scope for scope in scopes[0]]
    print(SCOPES)

    cred = None

    pickle_file = f'token_{API_SERVICE_NAME}_{API_VERSION}.pickle'
    # print(pickle_file)

    if os.path.exists(pickle_file):
        with open(pickle_file, 'rb') as token:
            cred = pickle.load(token)

    if not cred or not cred.valid:
        if cred and cred.expired and cred.refresh_token:
            cred.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRET_FILE, SCOPES)
            cred = flow.run_local_server()

    with open(pickle_file, 'wb') as token:
            pickle.dump(cred, token)

    try:
        service = build(API_SERVICE_NAME, API_VERSION, credentials=cred)
        #print(API_SERVICE_NAME, 'service created successfully')
        return service
    except Exception as e:
        print('Unable to connect.')
        print(e)
        return None

def search_file(pos,query):
    j=0
    client_secret='client_secrets.json'
    api_name='drive'
    api_version='v3'
    SCOPES = ['https://www.googleapis.com/auth/drive']
    service=Create_Service(client_secret,api_name,api_version,SCOPES)

    #query=f"parents='{'1ToFEFp77TSMfPlpkWDEMna8AbIPoDUSi'}' "
    response=service.files().list(q=query).execute()
    fichiers=[]
#fichiers=response.get('files')
    nextPage=response.get('files')

    nextPageToken=response.get('nextPageToken',None)
    totalFiles=0
    while True:
        nextTotalFiles=len(nextPage)+totalFiles
        if totalFiles <=pos and pos<nextTotalFiles:
            #print("fich trouvé", totalFiles,nextTotalFiles)
            fichiers=nextPage
            break
        if nextPageToken is None:
            break
        response=service.files().list(q=query,pageToken=nextPageToken).execute()
        totalFiles=nextTotalFiles
        nextPage=response.get('files')
        
        nextPageToken=response.get('nextPageToken',None)
        
    j=totalFiles

    for fich in fichiers :
        if j==pos:
            file_metadata={'name':fich['name'] ,'parents':['1gB3rWfeCbnxJNqQhtoz_xdV935fD0KAT']}
            service.files().copy(fileId=fich['id'] , body=file_metadata).execute()
            #print('oui',j,fich['name'])
            break
        j+=1


client_secret='client_secrets.json'
api_name='drive'
api_version='v3'
SCOPES = ['https://www.googleapis.com/auth/drive']
service=Create_Service(client_secret,api_name,api_version,SCOPES) 

#keys=hachage.generate_keypair(20)
#print(keys)
#pri_key=keys[0]
#pb_key=keys[-1]
ascii_codes=[]
#hachage.stateart(hachage.process("C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\dog_0124.jpg"))
i=0
secret_message=input("saisir votre message ")
for c in secret_message:
    ascii_codes.append(str(ord(c)))
#print(ascii_codes)
#lis=os.listdir("C:\\Users\\Administrateur\\state_art1\\sequence")
input_file=open("sequencestate.json","r")
#for rang in range (len(lis)):
    #input_file=open("C:\\Users\\Administrateur\\state_art1\\sequence\\"+lis[rang],"r")
    
hash_code=json.load(input_file)
localisation=[]
for i in range(len(ascii_codes)):
    for elt in hash_code.keys():
        if ascii_codes[i]==elt:
            for code in hash_code[elt]:
                    #print(code)
                if code[-1]==0:
                    query=f"parents='{'1hhtu7zstSU-2xV5vVNLiKsndE3-OvzIo'}' "
                 
                    search_file(code[0],query)
 
                    #localisation.append(int(hachage.encrypt(pb_key,code[0])))
                    #localisation.append([int(hachage.encrypt(pb_key,(code[0])[0])),int(hachage.encrypt(pb_key,(code[0])[1]))])
                    code[-1]=1
                    break
   # with open("C:\\Users\\Administrateur\\state_art1\\localisation\\localisation"+str(rang)+".json","w") as monfich:
   #     json.dump(localisation,monfich)
#with open("localisation.json","w") as monfich:
   #   json.dump(localisation,monfich) execution time for secret message: ceci est un message très secret. Exécutez toutes les directives: heure d'embarquement 13h
    #33min, number of copied files: 89
# Out:
# ['https://www.googleapis.com/auth/drive']
# saisir votre message ceci est un message très secret. Exécutez toutes les directives: heure d'embarquement 13h
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ['https://www.googleapis.com/auth/drive']
# ...

# %%
#main récepteur: parcours le stego-dossier et renvoie les séquences pour chacun des fichiers 

from __future__ import print_function
import pickle
import os
import time
from datetime import datetime
#from google_auth_oauthlib.flow import Flow, InstalledAppFlow
from googleapiclient.http import MediaFileUpload, MediaIoBaseDownload
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from pydrive.drive import GoogleDrive
from pydrive.auth import GoogleAuth
import google.auth
import google
from googleapiclient.discovery import build
from google.cloud import storage

from google.oauth2 import service_account
from googleapiclient.errors import HttpError
print(str(datetime.now()))

def Create_Service(client_secret_file, api_name, api_version, *scopes):
    CLIENT_SECRET_FILE = client_secret_file
    API_SERVICE_NAME = api_name
    API_VERSION = api_version
    SCOPES = [scope for scope in scopes[0]]
    print(SCOPES)

    cred = None

    pickle_file = f'token_{API_SERVICE_NAME}_{API_VERSION}.pickle'
    # print(pickle_file)

    if os.path.exists(pickle_file):
        with open(pickle_file, 'rb') as token:
            cred = pickle.load(token)

    if not cred or not cred.valid:
        if cred and cred.expired and cred.refresh_token:
            cred.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRET_FILE, SCOPES)
            cred = flow.run_local_server()

    with open(pickle_file, 'wb') as token:
            pickle.dump(cred, token)

    try:
        service = build(API_SERVICE_NAME, API_VERSION, credentials=cred)
        print(API_SERVICE_NAME, 'service created successfully')
        return service
    except Exception as e:
        print('Unable to connect.')
        print(e)
        return None


def search_position(name):#prend en paramètre le nom d'un fichier(contenu dans le stego-dossier) et renvoie [le numéro du répertoire qui le contient; sa position dans ce répertoire]
    numfolder=0
    numfile=0
    client_secret='client_secrets.json'
    api_name='drive'
    api_version='v3'
    SCOPES = ['https://www.googleapis.com/auth/drive']
    service=Create_Service(client_secret,api_name,api_version,SCOPES)
#parcours du rep "transactions"
    query=f"parents='{'1hhtu7zstSU-2xV5vVNLiKsndE3-OvzIo'}' "
    response=service.files().list(q=query).execute()
    files=response.get('files')
   # fichiers=[]
#fichiers=response.get('files')
    nextPage=response.get('files')
    nextPageToken=response.get('nextPageToken')
    ctrl=True
    
    while ctrl:
        fichiers=nextPage
        for fich in fichiers:
            
            if fich['name']==name:
                print(file['id']," ",file['name'])
                ctrl=False
                
                break
            numfile+=1
        if nextPageToken is None:
            break
        response=service.files().list(q=query,pageToken=nextPageToken).execute()
        nextPage=response.get('files')
        nextPageToken=response.get('nextPageToken',None)
        
    return numfile

client_secret='C:\\Users\\Administrateur\\Recepteur\\client_secrets.json'
api_name='drive'
api_version='v3'
SCOPES = ['https://www.googleapis.com/auth/drive']
service=Create_Service(client_secret,api_name,api_version,SCOPES)
liste=[]


query=f"parents='{'1gB3rWfeCbnxJNqQhtoz_xdV935fD0KAT'}' " 
response=service.files().list(q=query).execute()
files=[]
nextPage=response.get('files')
nextPageToken=response.get('nextPageToken',None)
while True:
    files=nextPage
    for file in files:
        print("nom du fichier recherché", file['name'])
        liste.append(search_position(file['name']))
        print("liste",liste)
    
    if nextPageToken is None:
        break
    response=service.files().list(q=query,pageToken=nextPageToken).execute()
    nextPage=response.get('files')
    nextPageToken=response.get('nextPageToken',None)

str(datetime.now())
#extraction time: 30min 46s
# Out:
# 2022-11-23 08:29:44.187778
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# nom du fichier recherché friel.txt
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# 1t3BS4OUqf8c7OUGfT9iHybs78aEAMFpT   friel.txt
# liste [4988]
# nom du fichier recherché walld.txt
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# 1T7GuKe2-Leffkbmsyn89Ti-ZGNyfPQOE   walld.txt
# liste [4988, 602]
# nom du fichier recherché staly.txt
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# 1d3PtR54HLIkHt0-ZQNeOByQzY5Z2kz11   staly.txt
# liste [4988, 602, 2657]
# nom du fichier recherché piple.txt
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# 1ea2gZOpGmaFvv3i9D4KhiiBBmXBFSDOH   piple.txt
# liste [4988, 602, 2657, 5651]
# nom du fichier recherché yevak.txt
# ['https://www.googleapis.com/auth/drive']
# drive service created successfully
# ...

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image, ImageFilter
# %matplotlib inline
image = cv2.imread('C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\dog_0124.jpg') # reads the image
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) # convert to HSV
figure_size = 9 # the dimension of the x and y axis of the kernal.
new_image = cv2.blur(image,(figure_size, figure_size))
plt.figure(figsize=(11,6))
plt.subplot(121), plt.imshow(cv2.cvtColor(image, cv2.COLOR_HSV2RGB)),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122), plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_HSV2RGB)),plt.title('Mean filter')
plt.xticks([]), plt.yticks([])
plt.show()
imgNG = new_image.convert('L')
im2 = imgNG.resize((512,512))
#cv2.imwrite("./image.png",new_image)

# %%
import cv2
import attacks
import os

lis=os.listdir("C:\\Users\\Administrateur\\Documents\\MASTER\\color_images")

for i in range(len(lis)):
    image= "C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\"+lis[i]
    chemin="C:\\Users\\Administrateur\\state_art1\\gaussianFilter_images\\"+lis[i]
    #gray_lena = cv2.imread(image, 0)

    # add salt and paper (0.01 is a proper parameter)
    #gray_lena = cv2.imread('C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\dog_0124.jpg', 0)

    # add salt and paper (0.01 is a proper parameter)
    #noise_lena = attacks.SaltAndPaper(gray_lena, 0.01)

    # use 3x3 mean filter
    #mean_3x3_lena = attacks.MedianFilter(noise_lena, 25)
    
    mean_3x3_lena = image_attacks.gaussian_filter(image, 5)
    cv2.imwrite(""+chemin, mean_3x3_lena)

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
import attack
image=cv2.imread('C:\\Users\\Administrateur\\Desktop\\mes_images\\072909.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
filtered_image = attack.mean_filter(image, 5)
#image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
#filtered_image = attack.gaussian_filter(image, 3)
filtered_image = cv2.cvtColor(image, cv2.COLOR_HSV2RGB)
cv2.imshow('Corrupted Image',filtered_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imwrite("./meanfilter.png",filtered_image)

# %%
import random
import cv2
 
def add_noise(img):
 
    # Getting the dimensions of the image
    row , col = img.shape
     
    # Randomly pick some pixels in the
    # image for coloring them white
    # Pick a random number between 300 and 10000
    number_of_pixels = random.randint(300, 10000)
    for i in range(number_of_pixels):
       
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
         
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
         
        # Color that pixel to white
        img[y_coord][x_coord] = 255
         
    # Randomly pick some pixels in
    # the image for coloring them black
    # Pick a random number between 300 and 10000
    number_of_pixels = random.randint(300 , 10000)
    for i in range(number_of_pixels):
       
        # Pick a random y coordinate
        y_coord=random.randint(0, row - 1)
         
        # Pick a random x coordinate
        x_coord=random.randint(0, col - 1)
         
        # Color that pixel to black
        img[y_coord][x_coord] = 0
         
    return img
# Out:
# 81

# %%
import cv2
import attacks

gray_lena = cv2.imread('C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\dog_0124.jpg', 0)

    # add salt and paper (0.01 is a proper parameter)
noise_lena = attacks.SaltAndPaper(gray_lena, 0.01)

    # use 3x3 mean filter
mean_3x3_lena = attacks.MeanFilter(noise_lena, 9)

cv2.imwrite("./meanfilter.jpg",mean_3x3_lena)
# Out:
# True

# %%
import os
import cv2
import hachage
import image_attacks
#lis=os.listdir("C:\\Users\\Administrateur\\Documents\\MASTER\\color_images")

#for i in range(len(lis)):
    image= "C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\"+lis[i]
  #chemin="C:\\Users\\Administrateur\\state_art1\\MedianFilter_images\\"+lis[i]
   #gray_lena = cv2.imread(image, 0)

    # add salt and paper (0.01 is a proper parameter)
    #noise_lena = image_attacks.SaltAndPepper(image, 0.01)
    
    #cv2.imwrite(chemin,image_attacks.MedianFilter(noise_lena,25))

#for i in range(len(lis)):
  image="C:\\Users\\Administrateur\\Documents\\MASTER\\color_images\\"+lis[i]
    
  hachage.algostate((hachage.process(image)),i)

lis=os.listdir("C:\\Users\\Administrateur\\state_art1\\gaussianFilter_images")
for i in range(len(lis)):
    image="C:\\Users\\Administrateur\\state_art1\\gaussianFilter_images\\"+lis[i]
    hachage.algostate((hachage.process(image)),i)

# %%
import json
import os
import hachage
bers=[]
ber=0
##pri_key=[640,520]
#pb_key=333961
#with open("emplacement.json","w") as monfich:
#    json.dump(plain,monfich)
#lis=os.listdir("C:\\Users\\Administrateur\\state_art1\\sequence_gf")
#lis1=os.listdir("C:\\Users\\Administrateur\\state_art1\\sequence")
#lis2=os.listdir("C:\\Users\\Administrateur\\state_art1\\localisation")
#n=len(lis)

#for a,b,c in zip(lis, lis1, lis2):
    #input_file=open("C:\\Users\\Administrateur\\state_art1\\sequence_gf\\"+a,"r")
    #sequencec=json.load(input_file)
    #input_file1=open("C:\\Users\\Administrateur\\state_art1\\sequence\\"+b,"r")
    #sequence=json.load(input_file1)
    #input_file2=open("C:\\Users\\Administrateur\\state_art1\\localisation\\"+c,"r")
    #localisation=json.load(input_file2)
input_file1=open("sequencestate.json","r")
sequence=json.load(input_file1)
#input_file2=open("localisation.json","r")
#localisation=json.load(input_file2)
       
#plain=[]
code=[]
#for elt in localisation:
    #plain.append([int(hachage.decrypt(pri_key,pb_key,elt[0])),int(hachage.decrypt(pri_key,pb_key,elt[1]))])
 #   plain.append(int(hachage.decrypt(pri_key,pb_key,elt)))
 #   print(plain)
    
#for elt in plain:
print(liste.reverse())
print(liste)

for elt in liste:
    for key in sequence.keys():
        for seq in sequence[key]:
            if seq[0]==elt:
                code.append(chr(int(key)))
print(''.join(code))
#liste=(hachage.bin_repr(''.join(code))).replace(" ","")
#print(liste)
#codes=[]
#for elt in plain:
#    for key in sequencec.keys():
  #      for seq in sequencec[key]:
 #           if seq[0]==elt:
  #              codes.append(chr(int(key)))
    #print("sequencec sequence ",sequencec, sequence)
    #liste1=(hachage.bin_repr(''.join(codes))).replace(" ","")
    #taille=len(liste)
    #d=0
   # for l,m in zip(liste, liste1):
    #    if l!=m:
    #        d+=1
   # ber+=d/taille
#ber=ber/n
#with open("bers_gf.json",'w') as monfich:
#    json.dump(ber,monfich)
#print("ber= ",ber)
# Out:
# None
# [1988, 44, 2658, 58, 137, 104, 1642, 1436, 784, 1052, 140, 1306, 255, 219, 2618, 6101, 1495, 884, 235, 1393, 1931, 307, 1525, 8464, 1940, 10789, 712, 2822, 958, 1212, 2259, 1160, 1941, 239, 500, 670, 3253, 1441, 2805, 1660, 177, 4139, 3175, 10, 2425, 4748, 2402, 11901, 4255, 41, 2447, 12069, 4753, 18, 259, 1626, 2879, 5775, 5863, 569, 33, 2941, 12449, 112, 5083, 642, 3060, 2925, 2529, 3213, 5159, 99, 64, 3256, 378, 564, 3150, 3191, 5835, 3752, 3275, 422, 3286, 2092, 8004, 5651, 2657, 602, 4988]
# ceci est un message très secret. Exécutez toutes les directives: heure d'embarquement 13h

# %%
import hachage
(hachage.bin_repr("nbj")).replace(" ","")
# Out:
# '011011100110001001101010'

# %%
liste="10001011110"
liste2="10010001011"
liste1="10011100110"
#for i in range(len(liste)):
        
for l,m,n in zip(liste, liste1,liste2):
    print(l!=m,l!=n)

# %%
client_secret='client_secrets.json'
api_name='drive'
api_version='v3'
SCOPES = ['https://www.googleapis.com/auth/drive']
service=algo_sheet.Create_Service(client_secret,api_name,api_version,SCOPES)


query=f"parents='{'11S_NVlwN5f8MUA2vVqD6AFQOaziHcMmg'}' "
response=service.files().list(q=query).execute()
files=response.get('files')
nextPageToken=response.get('nextPageToken')
for file in files:
                    
    query=f"parents='{file['id']}' "
                        
    algo_sheet.search_file(,query)

# %%
import hachage
import json
import os
lis=os.listdir("C:\\Users\\Administrateur\\Downloads\\real_dataset")
nbr=0    
for i in range(len(lis)):
    image= "C:\\Users\\Administrateur\\Downloads\\real_dataset\\"+lis[i]
    hachage.stateart(hachage.process(image))
    input_file=open('C:\\Users\\Administrateur\\state_art1\\sequencestate.json', 'r')
    var_json=json.load(input_file)
    if len(var_json.keys())==256:
        nbr+=1
        
   # else:
      #  os.remove(image)
print(nbr) #sweet images: 729 on 885, execution time: 2h30min
# C:\\Users\\Administrateur\\Downloads\\real_dataset sweet images:106 on 108 , execution time: 27 min
# Out:
# 106
